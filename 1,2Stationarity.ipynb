# %%
#import packages
import os
os.getcwd()
# Out:
# 'C:\\Users\\ACER'

# %%
import yfinance as yf
import plotly.graph_objects as go

# %%
pip install yfinance
# Out:
#   Cell In[15], line 1
#     pip install yfinance
#         ^
# SyntaxError: invalid syntax

# %%
#define thestock and time period
ticker_symbol = 'AAPL'
start_date = '2021-01-01'
end_date = '2023-01-01'

# %%
data = yf.download(ticker_symbol, start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2021-01-04  125.856720  129.941395  123.279481  129.853870  143301900
# 2021-01-05  127.412697  128.122663  124.903537  125.350913   97664900
# 2021-01-06  123.123856  127.451673  122.909895  124.213106  155088000
# 2021-01-07  127.325241  128.015753  124.349264  124.835535  109578200
# 2021-01-08  128.424179  128.988255  126.654145  128.793735  105158200
# ...                ...         ...         ...         ...        ...
# 2022-12-23  129.778854  130.330013  127.593891  128.853688   63814900
# 2022-12-27  127.977737  129.335962  126.688416  129.306436   69007800
# 2022-12-28  124.050705  128.961945  123.883390  127.623410   85438400
# 2022-12-29  127.564377  128.420641  125.714051  125.969942   75703700
# 2022-12-30  127.879333  127.899022  125.418798  126.383334   77034200
#
# [503 rows x 5 columns]

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=data.index, y=data['Close'], mode='lines', name='close price'))
fig.update_layout(title=f'{ticker_symbol} stock prices from Yahoo FInance',
                  xaxis_title='Date',
                  yaxis_title='price',
                  template='simple_white',
                  width=900,
                  height=500)
fig.show()
